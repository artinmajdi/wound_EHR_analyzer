# %%
import pandas as pd
# from app2_refactored import DataManager

dataset_path = '/Users/artinmajdi/Documents/GitHubs/postdoc/Wound_management_interpreter_LLM/dataset/SmartBandage-Data_for_llm.csv'

df = pd.read_csv(dataset_path)
df.head()
# Out:
#    Record ID                   Event Name         MRN Date of Birth     Sex  \
# 0          1     Visit 1 (Arm 2: Control)  41758670.0      6/9/1996  Female
# 1          2     Visit 1 (Arm 2: Control)  41271032.0     1/23/1992    Male
# 2          3  Visit 1  (Arm 1: Treatment)  41657125.0     8/29/1956    Male
# 3          3   Visit 2 (Arm 1: Treatment)         NaN           NaN     NaN
# 4          3   Visit 3 (Arm 1: Treatment)         NaN           NaN     NaN
#
#               Race  Race: Other - Specify               Ethnicity   Weight  \
# 0  White/ Caucasian                    NaN      Hispanic or Latino    93.3
# 1  White/ Caucasian                    NaN      Hispanic or Latino    99.0
# 2             Black                    NaN  Not Hispanic or Latino   111.2
# 3               NaN                    NaN                     NaN     NaN
# 4               NaN                    NaN                     NaN     NaN
#
#    Height   ...  Clinical events   \
# 0   157.48  ...               NaN
# 1   182.00  ...               NaN
# 2   180.34  ...               NaN
# 3      NaN  ...               NaN
# 4      NaN  ...               NaN
#
#   Diabetic Foot Wound - WIfI Classification: foot Infection (fI) Infection  \
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                         Uninfected                   NaN
# 3                                                NaN                   NaN
# 4                                         Uninfected                   NaN
#
#    Infection/ Biomarker Measurement                  Granulation  \
# 0                                NaN                         NaN
# 1                                NaN                         NaN
# 2                                NaN  One half of the wound area
# 3                                NaN                         NaN
# 4                                NaN                         NaN
#
#   Granulation Quality         Necrosis  Exudate Volume Exudate Viscosity  \
# 0                  NaN              NaN            NaN               NaN
# 1                  NaN              NaN            NaN               NaN
# 2                 Pale  Adherent Slough           High            Medium
# 3                  NaN              NaN            NaN               NaN
# 4                  NaN              NaN         Medium            Medium
#
#   Exudate Type
# 0           NaN
# 1           NaN
# 2        Yellow
# 3           NaN
# 4        Yellow
#
# [5 rows x 70 columns]

# %%
# Out:
# ['Record ID',
#  'Event Name',
#  'MRN',
#  'Date of Birth',
#  'Sex',
#  'Race ',
#  'Race: Other - Specify ',
#  'Ethnicity ',
#  'Weight',
#  'Height ',
#  'BMI ',
#  'Study Cohort ',
#  'Smoking status',
#  'Number of Packs per Day(average number of cigarette packs smoked per day)1 Pack= 20 Cigarettes',
#  'Number of Years smoked/has been smoking cigarettes',
#  'Alcohol Use Status ',
#  'Number of alcohol drinks consumed/has been consuming',
#  'Illicit drug use?',
#  'Current type of drug use:',
#  'Former type of drug use:',
#  'How often has the patient used these substances in the past 3 months?',
#  'IV drug use?',
#  'Medical History (select all that apply)',
#  'Diabetes?',
#  'Respiratory',
#  'Cardiovascular ',
#  'Gastrointestinal',
#  'Musculoskeletal',
#  'Endocrine/ Metabolic',
#  'Hematopoietic',
#  'Hepatic/Renal',
#  'Neurologic',
#  'Immune',
#  'Other Medical History',
#  'A1c  available within the last 3 months?',
#  'Hemoglobin A1c (%)',
#  'Skipped Visit?',
#  'Visit date ',
#  'Calculated Age at Enrollment',
#  'Oxygenation (%)',
#  'Hemoglobin Level',
#  'Oxyhemoglobin Level',
#  'Deoxyhemoglobin Level',
#  'Center of Wound Temperature (Fahrenheit)',
#  'Edge of Wound Temperature (Fahrenheit)',
#  'Peri-wound Temperature (Fahrenheit)',
#  'Skin Impedance (kOhms) - Z',
#  "Skin Impedance (kOhms) - Z'",
#  "Skin Impedance (kOhms) - Z''",
#  'Target wound onset date ',
#  'Length (cm)',
#  'Width (cm)',
#  'Depth (cm)',
#  'Calculated Wound Area',
#  'Describe the wound location',
#  'Is there undermining/ tunneling? ',
#  'Undermining Location Description',
#  'Tunneling Location Description',
#  'Wound Type ',
#  'Current wound care ',
#  'Clinical events ',
#  'Diabetic Foot Wound - WIfI Classification: foot Infection (fI)',
#  'Infection',
#  'Infection/ Biomarker Measurement ',
#  'Granulation',
#  'Granulation Quality ',
#  'Necrosis ',
#  'Exudate Volume',
#  'Exudate Viscosity',
#  'Exudate Type ']

# %%
from llm_interface import WoundAnalysisLLM
from data_processor import WoundDataProcessor
from app2_refactored import DataManager

dataset_path = '/Users/artinmajdi/Documents/GitHubs/postdoc/Wound_management_interpreter_LLM/dataset/SmartBandage-Data_for_llm.csv'


# df = DataManager.load_data(dataset_path)

df2 = DataManager._preprocess_data(df)

df2
# Out:
# /Users/artinmajdi/Documents/GitHubs/postdoc/Wound_management_interpreter_LLM/wound_analysis/app2_refactored.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Visit Number'] = df['Event Name'].str.extract(r'Visit (\d+)').fillna(1).astype(int)
# /Users/artinmajdi/Documents/GitHubs/postdoc/Wound_management_interpreter_LLM/wound_analysis/app2_refactored.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Visit date'] = pd.to_datetime(df['Visit date']).dt.strftime('%m-%d-%Y')
# /Users/artinmajdi/Documents/GitHubs/postdoc/Wound_management_interpreter_LLM/wound_analysis/app2_refactored.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Wound Type'] = pd.Categorical(df['Wound Type'].fillna('Unknown'), categories=df['Wound Type'].dropna().unique())
# /Users/artinmajdi/Documents/GitHubs/postdoc/Wound_management_interpreter_LLM/wound_analysis/app2_refactored.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Center-Edge Temp Gradient'] = df[center] - df[edge]
# /Users/artinmajdi/Documents/GitHubs/postdoc/Wound_management_interpreter_LLM/wound_analysis/app2_refactored.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Edge-Peri Temp Gradient']   = df[edge]   - df[peri]
# /Users/artinmajdi/Documents/GitHubs/postdoc/Wound_management_interpreter_LLM/wound_analysis/app2_refactored.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Temp Gradient']       = df[center] - df[peri]
# /Users/artinmajdi/Documents/GitHubs/postdoc/Wound_management_interpreter_LLM/wound_analysis/app2_refactored.py:192: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BMI Category'] = pd.cut(
# /Users/artinmajdi/Documents/GitHubs/postdoc/Wound_management_interpreter_LLM/wound_analysis/app2_refactored.py:200: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Visit date'] = pd.to_datetime(df['Visit date'])#.dt.strftime('%m-%d-%Y')
# /Users/artinmajdi/Documents/GitHubs/postdoc/Wound_management_interpreter_LLM/wound_analysis/app2_refactored.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Days_Since_First_Visit'] = df.groupby('Record ID')['Visit date'].transform(
# /Users/artinmajdi/Documents/GitHubs/postdoc/Wound_management_interpreter_LLM/wound_analysis/app2_refactored.py:208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Healing Rate (%)'] = pd.Series(0.0, index=df.index, dtype=float)
# /Users/artinmajdi/Documents/GitHubs/postdoc/Wound_management_interpreter_LLM/wound_analysis/app2_refactored.py:209: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Estimated_Days_To_Heal'] = pd.Series(np.nan, index=df.index, dtype=float)
# /Users/artinmajdi/Documents/GitHubs/postdoc/Wound_management_interpreter_LLM/wound_analysis/app2_refactored.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Overall_Improvement'] = pd.Series(np.nan, index=df.index, dtype=str)
# /Users/artinmajdi/Documents/GitHubs/postdoc/Wound_management_interpreter_LLM/wound_analysis/app2_refactored.py:165: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Average Healing Rate (%)'] = df.groupby('Record ID')['Healing Rate (%)'].transform('mean')
#      Record ID                   Event Name         MRN Date of Birth     Sex  \
# 0            1     Visit 1 (Arm 2: Control)  41758670.0      6/9/1996  Female
# 1            2     Visit 1 (Arm 2: Control)  41271032.0     1/23/1992    Male
# 2            3  Visit 1  (Arm 1: Treatment)  41657125.0     8/29/1956    Male
# 4            3   Visit 3 (Arm 1: Treatment)         NaN           NaN     NaN
# 6            3   Visit 5 (Arm 1: Treatment)         NaN           NaN     NaN
# ..         ...                          ...         ...           ...     ...
# 413         63   Visit 3 (Arm 1: Treatment)         NaN           NaN     NaN
# 414         64  Visit 1  (Arm 1: Treatment)   7080625.0     2/13/1950    Male
# 415         64   Visit 2 (Arm 1: Treatment)         NaN           NaN     NaN
# 416         65  Visit 1  (Arm 1: Treatment)  41813237.0     7/16/1972    Male
# 417         66  Visit 1  (Arm 1: Treatment)  41652335.0    11/21/1986    Male
#
#                   Race Race: Other - Specify               Ethnicity  Weight  \
# 0     White/ Caucasian                   NaN      Hispanic or Latino   93.30
# 1     White/ Caucasian                   NaN      Hispanic or Latino   99.00
# 2                Black                   NaN  Not Hispanic or Latino  111.20
# 4                  NaN                   NaN                     NaN     NaN
# 6                  NaN                   NaN                     NaN     NaN
# ..                 ...                   ...                     ...     ...
# 413                NaN                   NaN                     NaN     NaN
# 414   White/ Caucasian                   NaN  Not Hispanic or Latino   84.09
# 415                NaN                   NaN                     NaN     NaN
# 416   White/ Caucasian                   NaN      Hispanic or Latino   87.80
# 417  Two or more races                   NaN  Not Hispanic or Latino  153.20
#
#      Height  ...  Visit Number Center-Edge Temp Gradient  \
# 0    157.48  ...             1                      -0.2
# 1    182.00  ...             1                       NaN
# 2    180.34  ...             1                       NaN
# 4       NaN  ...             3                       NaN
# 6       NaN  ...             5                       NaN
# ..      ...  ...           ...                       ...
# 413     NaN  ...             3                      -2.4
# 414  182.80  ...             1                      -0.8
# 415     NaN  ...             2                      -0.2
# 416  177.80  ...             1                       0.0
# 417  195.58  ...             1                      -1.4
#
#     Edge-Peri Temp Gradient  Total Temp Gradient  BMI Category  \
# 0                       0.4                  0.2  Obese II-III
# 1                       NaN                  NaN    Overweight
# 2                       NaN                  NaN       Obese I
# 4                       NaN                  NaN           NaN
# 6                       NaN                  NaN           NaN
# ..                      ...                  ...           ...
# 413                     1.1                 -1.3           NaN
# 414                    -0.3                 -1.1    Overweight
# 415                     1.5                  1.3           NaN
# 416                     0.0                  0.0    Overweight
# 417                     0.4                 -1.0  Obese II-III
#
#     Days_Since_First_Visit Healing Rate (%) Estimated_Days_To_Heal  \
# 0                      0.0         0.000000                    NaN
# 1                      0.0         0.000000                    NaN
# 2                      0.0         0.000000              70.965157
# 4                     16.0       -14.765101              70.965157
# 6                     31.0        12.280702              70.965157
# ..                     ...              ...                    ...
# 413                   14.0        66.282051              15.508704
# 414                    0.0         0.000000              10.294118
# 415                    7.0        30.357143              10.294118
# 416                    0.0         0.000000                    NaN
# 417                    0.0         0.000000                    NaN
#
#     Overall_Improvement Average Healing Rate (%)
# 0                    No                 0.000000
# 1                    No                 0.000000
# 2                   NaN                 5.103120
# 4                   NaN                 5.103120
# 6                   NaN                 5.103120
# ..                  ...                      ...
# 413                 Yes                33.141026
# 414                 NaN                15.178571
# 415                 Yes                15.178571
# 416                  No                 0.000000
# 417                  No                 0.000000
#
# [308 rows x 80 columns]

# %%
columns = ["Skin Impedance (kOhms) - Z","Skin Impedance (kOhms) - Z'", "Skin Impedance (kOhms) - Z''"]
print(df2.columns)
# Out:
# Index(['Record ID', 'Event Name', 'MRN', 'Date of Birth', 'Sex', 'Race',
#        'Race: Other - Specify', 'Ethnicity', 'Weight', 'Height', 'BMI',
#        'Study Cohort', 'Smoking status',
#        'Number of Packs per Day(average number of cigarette packs smoked per day)1 Pack= 20 Cigarettes',
#        'Number of Years smoked/has been smoking cigarettes',
#        'Alcohol Use Status',
#        'Number of alcohol drinks consumed/has been consuming',
#        'Illicit drug use?', 'Current type of drug use:',
#        'Former type of drug use:',
#        'How often has the patient used these substances in the past 3 months?',
#        'IV drug use?', 'Medical History (select all that apply)', 'Diabetes?',
#        'Respiratory', 'Cardiovascular', 'Gastrointestinal', 'Musculoskeletal',
#        'Endocrine/ Metabolic', 'Hematopoietic', 'Hepatic/Renal', 'Neurologic',
#        'Immune', 'Other Medical History',
#        'A1c  available within the last 3 months?', 'Hemoglobin A1c (%)',
#        'Skipped Visit?', 'Visit date', 'Calculated Age at Enrollment',
#        'Oxygenation (%)', 'Hemoglobin Level', 'Oxyhemoglobin Level',
#        'Deoxyhemoglobin Level', 'Center of Wound Temperature (Fahrenheit)',
#        'Edge of Wound Temperature (Fahrenheit)',
#        'Peri-wound Temperature (Fahrenheit)', 'Skin Impedance (kOhms) - Z',
#        'Skin Impedance (kOhms) - Z'', 'Skin Impedance (kOhms) - Z''',
#        'Target wound onset date', 'Length (cm)', 'Width (cm)', 'Depth (cm)',
#        'Calculated Wound Area', 'Describe the wound location',
#        'Is there undermining/ tunneling?', 'Undermining Location Description',
#        'Tunneling Location Description', 'Wound Type', 'Current wound care',
#        'Clinical events',
#        'Diabetic Foot Wound - WIfI Classification: foot Infection (fI)',
#        'Infection', 'Infection/ Biomarker Measurement', 'Granulation',
#        'Granulation Quality', 'Necrosis', 'Exudate Volume',
#        'Exudate Viscosity', 'Exudate Type', 'Visit Number',
#        'Center-Edge Temp Gradient', 'Edge-Peri Temp Gradient',
#        'Total Temp Gradient', 'BMI Category', 'Days_Since_First_Visit',
#        'Healing Rate (%)', 'Estimated_Days_To_Heal', 'Overall_Improvement',
#        'Average Healing Rate (%)'],
#       dtype='object')

# %% [markdown]
# "## Clinical Population Analysis Task\n\n**Context**: Analyze this wound care dataset from a smart bandage clinical trial. Focus on identifying clinically significant patterns, risk factors, and treatment outcomes.\n\n**Dataset Overview**:\n- Patients: N/A | Wounds: N/A\n- Study Duration: N/A | Avg Visits/Patient: N/A\n\n## 1. Patient Characteristics\n### Core Demographics:\n- Age: {'summary': 'Mean: 52.8, Median: 52.5', 'distribution': {52.0: 4, 42.0: 4, 67.0: 3, 62.0: 3, 30.0: 3, 65.0: 3, 44.0: 2, 71.0: 2, 70.0: 2, 43.0: 2, 64.0: 2, 74.0: 2, 56.0: 2, 76.0: 2, 37.0: 2, 38.0: 2, 59.0: 2, 51.0: 2, 26.0: 2, 75.0: 1, 36.0: 1, 63.0: 1, 72.0: 1, 80.0: 1, 53.0: 1, 47.0: 1, 50.0: 1, 28.0: 1, 68.0: 1, 58.0: 1, 82.0: 1, 24.0: 1, 34.0: 1, 57.0: 1, 48.0: 1, 31.0: 1, 33.0: 1, 78.0: 1, 2.0: 1}, 'age_groups': {'50-70': 28, '30-50': 19, '>70': 11, '<30': 8}} | Gender: {'Male': 38, 'Female': 28}\n- BMI: {'summary': 'Mean: 34.0, Range: 18.6-218.5', 'distribution': {'Obese': 30, 'Overweight': 18, 'Normal': 15, 'Underweight': 0}, 'by_healing_status': {'mean': {'Underweight': nan, 'Normal': 0.0, 'Overweight': 0.0, 'Obese': 0.0}, 'count': {'Underweight': 0, 'Normal': 15, 'Overweight': 18, 'Obese': 30}}} | Race/Ethnicity: {'White/ Caucasian': 58, 'Black': 2, 'Other {race_oth}': 2, 'Two or more races': 2, 'Asian': 1, 'American Indian/ Alaskan Native': 1}\n\n### Comorbidity Profile:\n- Diabetes: N/A\n- Smoking: N/A\n- Vascular Disease: N/A\n\n## 2. Wound Characteristics\n### Typology:\n- Primary Types: N/A\n- Locations: N/A\n### Severity Metrics:\n- Initial Size: N/A\n- Depth Grades: N/A\n- Infection Rates: N/A\n\n## 3. Therapeutic Outcomes\n### Intervention Analysis:\n- Modalities Used: N/A\n- Response Times: N/A\n### Efficacy Metrics:\n- Healing Rates: N/A\n- Complication Profile: N/A\n\n## 4. Biomarker Correlations\n### Smart Bandage Metrics:\n- Temperature Trends: N/A\n- Impedance Dynamics: N/A\n- Oxygenation Levels: N/A\n\n### Healing Correlations:\n- Early Healing Indicators: N/A\n- Complication Predictors: N/A\n\n## Analysis Requirements\n1. Perform stratified analysis by wound type and patient comorbidities\n2. Identify significant correlations between sensor data and healing trajectories\n3. Evaluate treatment effectiveness with adjustment for confounding factors\n4. Provide clinical actionability scores for key findings\n5. Generate SMART clinical recommendations with implementation steps\n\n**Output Format**:\n- Structured clinical report with executive summary\n- Evidence-graded recommendations (Levels A-D)\n- Risk-benefit analysis for proposed interventions"
